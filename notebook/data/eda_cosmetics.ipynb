# %%
# !python -m pip install paddlepaddle -i https://mirror.baidu.com/pypi/simple
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple
# ...

# %%
# !pip install paddleocr
# Out:
# ...
#   Using cached paddleocr-2.7.0.3-py3-none-any.whl.metadata (26 kB)
# ...
#   Using cached shapely-2.0.2-cp38-cp38-macosx_11_0_arm64.whl.metadata (7.0 kB)
# ...
#   Using cached scikit_image-0.21.0-cp38-cp38-macosx_12_0_arm64.whl.metadata (14 kB)
# ...
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# ...
#   Using cached pyclipper-1.3.0.post5-cp38-cp38-macosx_10_9_universal2.whl.metadata (9.0 kB)
# ...
#   Using cached lmdb-1.4.1-cp38-cp38-macosx_11_0_arm64.whl
# ...
#   Using cached visualdl-2.5.3-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached rapidfuzz-3.6.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached opencv_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (30.0 MB)
# ...
#   Using cached opencv_contrib_python-4.6.0.66-cp37-abi3-macosx_11_0_arm64.whl (38.9 MB)
# ...
#   Using cached Cython-3.0.8-py2.py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached lxml-5.1.0-cp38-cp38-macosx_10_9_universal2.whl.metadata (3.5 kB)
# ...
#   Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# ...
